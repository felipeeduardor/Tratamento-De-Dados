# %%
# import as biblioteca
import pandas as pd
import seaborn as srn
import statistics as sts

# %%
#importa dados
dataset = pd.read_csv('/content/Churn.csv',sep=';')
dataset.head()
# Out:
#    X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0   1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1   2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2   3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3   4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4   5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0

# %%
#tamanho
dataset.shape
# Out:
# (999, 12)

# %%
dataset.columns=['ID','SCORE','ESTADO','GENERO','IDADE','PATRÍMONIO','SALDO','PRODUTOS','TEMCARTCREDITO','ATIVO','SALARIO','SAIU']

# %%
dataset
# Out:
#        ID  SCORE ESTADO     GENERO  IDADE  PATRÍMONIO     SALDO  PRODUTOS  \
# 0       1    619     RS   Feminino     42           2         0         1
# 1       2    608     SC   Feminino     41           1   8380786         1
# 2       3    502     RS   Feminino     42           8   1596608         3
# 3       4    699     RS   Feminino     39           1         0         2
# 4       5    850     SC   Feminino     43           2  12551082         1
# ..    ...    ...    ...        ...    ...         ...       ...       ...
# 994   996    838     SC  Masculino     43           9  12310588         2
# 995   997    610     SC  Masculino     29           9         0         3
# 996   998    811     SC  Masculino     44           3         0         2
# 997   999    587     SC  Masculino     62           7  12128627         1
# 998  1000    811     PR   Feminino     28           4  16773882         2
#
#      TEMCARTCREDITO  ATIVO     SALARIO  SAIU
# ...

# %%
#explora dados categorico
#estado
agrupado = dataset.groupby(['ESTADO']).size()
agrupado
# Out:
# ESTADO
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
agrupado.plot.bar(color='green')
# Out:
# <Axes: xlabel='ESTADO'>

# %%
agrupado = dataset.groupby(['GENERO']).size()
agrupado
# Out:
# GENERO
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
agrupado.plot.bar(color='grey')
# Out:
# <Axes: xlabel='GENERO'>

# %%
#explora colunas numerica
dataset['SCORE'].describe()
# Out:
# count    999.000000
# mean     648.621622
# std       98.264219
# min      376.000000
# 25%      580.000000
# 50%      653.000000
# 75%      721.000000
# max      850.000000
# Name: SCORE, dtype: float64

# %%
srn.boxplot(dataset['SCORE']).set_title('SCORE')
# Out:
# Text(0.5, 1.0, 'SCORE')

# %%
srn.distplot(dataset['SCORE']).set_title('SCORE')
# Out:
# <ipython-input-12-c34ea57a0dae>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['SCORE']).set_title('SCORE')
# Text(0.5, 1.0, 'SCORE')

# %%
dataset['IDADE'].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: IDADE, dtype: float64

# %%
srn.boxplot(dataset['IDADE']).set_title('IDADE')
# Out:
# Text(0.5, 1.0, 'IDADE')

# %%
srn.distplot(dataset['IDADE']).set_title('IDADE')
# Out:
# <ipython-input-15-cd2a0e8e8c82>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['IDADE']).set_title('IDADE')
# Text(0.5, 1.0, 'IDADE')

# %%
srn.barplot(dataset['IDADE']).set_title('IDADE')
# Out:
# Text(0.5, 1.0, 'IDADE')

# %%
#saldo
dataset['SALDO'].describe()
# Out:
# count    9.990000e+02
# mean     7.164928e+06
# std      6.311840e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.958835e+06
# 75%      1.258684e+07
# max      2.117743e+07
# Name: SALDO, dtype: float64

# %%
srn.boxplot(dataset['SALDO']).set_title('SALDO')
# Out:
# Text(0.5, 1.0, 'SALDO')

# %%
srn.distplot(dataset['SALDO']).set_title('SALDO');
# Out:
# <ipython-input-19-a4c527260c53>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['SALDO']).set_title('SALDO');

# %%
#salario
dataset['SALARIO'].describe( )
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: SALARIO, dtype: float64

# %%
srn.boxenplot(dataset['SALARIO']).set_title('SALARIO')
# Out:
# Text(0.5, 1.0, 'SALARIO')

# %%
srn.boxplot(dataset['SALARIO']).set_title('SALARIO')
# Out:
# Text(0.5, 1.0, 'SALARIO')

# %%
srn.catplot(dataset['SALARIO'])

# %%
srn.distplot(dataset['SALARIO']). set_title('SALARIO')
# Out:
# <ipython-input-24-ac0400b3f546>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['SALARIO']). set_title('SALARIO')
# Text(0.5, 1.0, 'SALARIO')

# %%
#contamos valores nas
#salario GENERO
dataset.isnull().sum()
# Out:
# ID                0
# SCORE             0
# ESTADO            0
# GENERO            8
# IDADE             0
# PATRÍMONIO        0
# SALDO             0
# PRODUTOS          0
# TEMCARTCREDITO    0
# ATIVO             0
# SALARIO           7
# SAIU              0
# dtype: int64

# %%
#salario
#remove nas e subistitur para mediana
dataset['SALARIO'].describe()
# Out:
# count    9.920000e+02
# mean     3.528762e+07
# std      5.305800e+08
# min      9.677000e+03
# 25%      3.029011e+06
# 50%      8.703250e+06
# 75%      1.405213e+07
# max      1.193469e+10
# Name: SALARIO, dtype: float64

# %%
mediana = sts.median(dataset['SALARIO'])
mediana
# Out:
# 70518.0

# %%
dataset['SALARIO'].fillna(mediana,inplace=True)

# %%
dataset['SALARIO'].isnull().sum()
# Out:
# 0

# %%
#falta de padronização e nas
agrupado = dataset.groupby(['GENERO']).size()
agrupado
# Out:
# GENERO
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
#total de nas
dataset['GENERO'].isnull().sum()
# Out:
# 8

# %%
#preenche nas com  masculino que e moda
dataset['GENERO'].fillna('Masculino',inplace=True)

# %%
#total de nas
dataset['GENERO'].isnull().sum()
# Out:
# 0

# %%
#padroniza de acordo com o dominio
dataset.loc[dataset['GENERO']=='M','GENERO' ]='Masculino'
dataset.loc[dataset['GENERO'].isin(['Fem','F']),'GENERO'] ='Feminino'
agrupado= dataset.groupby(['GENERO']).size()
agrupado
# Out:
# GENERO
# Feminino     464
# Masculino    535
# dtype: int64

# %%
mediana=sts.median(dataset['IDADE'])
mediana
# Out:
# 37

# %%
#idade fora do dominios
dataset['IDADE'].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: IDADE, dtype: float64

# %%
dataset.loc[(dataset['IDADE'] < 0)|(dataset['IDADE']>120),'IDADE']=mediana

# %%
dataset.loc[(dataset['IDADE'] < 0)|(dataset['IDADE']>120)]
# Out:
#                 ID       SCORE       IDADE  PATRÍMONIO         SALDO  \
# count   999.000000  999.000000  999.000000  999.000000  9.990000e+02
# mean    500.916917  648.621622   38.903904    5.069069  7.164928e+06
# std     288.662884   98.264219   10.672421    2.927691  6.311840e+06
# min       1.000000  376.000000    0.000000    0.000000  0.000000e+00
# 25%     251.500000  580.000000   32.000000    2.000000  0.000000e+00
# 50%     501.000000  653.000000   37.000000    5.000000  8.958835e+06
# 75%     750.500000  721.000000   44.000000    8.000000  1.258684e+07
# max    1000.000000  850.000000   82.000000   10.000000  2.117743e+07
#
#          PRODUTOS  TEMCARTCREDITO      ATIVO       SALARIO        SAIU
# count  999.000000      999.000000  999.00000  9.990000e+02  999.000000
# mean     1.526527        0.702703    0.50951  3.504085e+07    0.203203
# std      0.574201        0.457297    0.50016  5.287241e+08    0.402584
# ...

# %%
#idade fora do dominios
dataset['IDADE'].describe()
# Out:
# count    999.000000
# mean      38.903904
# std       10.672421
# min        0.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max       82.000000
# Name: IDADE, dtype: float64

# %%
from pandas.core.base import duplicated

#dados duplicado buscano id
dataset[dataset.duplicated(['ID'],keep=False)]
# Out:
#     ID  SCORE ESTADO    GENERO  IDADE  PATRÍMONIO    SALDO  PRODUTOS  \
# 80  81    665     RS  Feminino     34           1  9664554         2
# 81  81    665     RS  Feminino     34           1  9664554         2
#
#     TEMCARTCREDITO  ATIVO     SALARIO  SAIU
# 80               0      0  17141366.0     0
# 81               0      0  17141366.0     0

# %%
#expluir pela ID
dataset.drop_duplicates(subset='ID',keep='first',inplace=True)

#buscando duplicados
dataset[dataset.duplicated(['ID'],keep=False)]
# Out:
# Empty DataFrame
# Columns: [ID, SCORE, ESTADO, GENERO, IDADE, PATRÍMONIO, SALDO, PRODUTOS, TEMCARTCREDITO, ATIVO, SALARIO, SAIU]
# Index: []

# %%
#estado fora do dominio
agrupado = dataset.groupby(['ESTADO']).size()
agrupado
# Out:
# ESTADO
# PR    257
# RP      1
# RS    477
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
#atribuimos rs (moda)
dataset.loc[dataset['ESTADO'].isin(['RP','SP','TD']),'ESTADO']='RS'
agrupado = dataset.groupby(['ESTADO']).size()

# %%
#verifica as resposta
agrupado
# Out:
# ESTADO
# PR    257
# RS    483
# SC    258
# dtype: int64

# %%
#outliers em salario , vamos considera dois desvio padrao
desv= sts.stdev(dataset['SALARIO'])
desv
# Out:
# 528988918.4679201

# %%
#definir padrão como maior valor
dataset.loc[dataset['SALARIO']>=2*desv]
# Out:
#       ID  SCORE ESTADO     GENERO  IDADE  PATRÍMONIO     SALDO  PRODUTOS  \
# 7      8    376     PR   Feminino     29           4  11504674         4
# 116  118    668     PR   Feminino     37           6   1678644         1
# 170  172    484     RS   Feminino     29           4  13011439         1
# 230  232    673     RS  Masculino     72           1         0         2
#
#      TEMCARTCREDITO  ATIVO       SALARIO  SAIU
# 7                 1      0  1.193469e+10     1
# 116               1      0  1.156383e+10     0
# 170               1      0  1.640179e+09     0
# 230               0      1  1.119812e+09     0

# %%
#vamos avaliar salario com a mediana
mediana= sts.median(dataset['SALARIO'])
mediana
# Out:
# 8637195.5

# %%
#atribuimos
dataset.loc[dataset['SALARIO']>=2*desv,'SALARIO']= mediana
#checamos se algum atende os criterio
dataset.loc[dataset['SALARIO']>=2*desv]
# Out:
# Empty DataFrame
# Columns: [ID, SCORE, ESTADO, GENERO, IDADE, PATRÍMONIO, SALDO, PRODUTOS, TEMCARTCREDITO, ATIVO, SALARIO, SAIU]
# Index: []

# %%
dataset.head()
# Out:
#    ID  SCORE ESTADO    GENERO  IDADE  PATRÍMONIO     SALDO  PRODUTOS  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    TEMCARTCREDITO  ATIVO     SALARIO  SAIU
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0

# %%
dataset.tail()
# Out:
#        ID  SCORE ESTADO     GENERO  IDADE  PATRÍMONIO     SALDO  PRODUTOS  \
# 994   996    838     SC  Masculino     43           9  12310588         2
# 995   997    610     SC  Masculino     29           9         0         3
# 996   998    811     SC  Masculino     44           3         0         2
# 997   999    587     SC  Masculino     62           7  12128627         1
# 998  1000    811     PR   Feminino     28           4  16773882         2
#
#      TEMCARTCREDITO  ATIVO     SALARIO  SAIU
# 994               1      0  14576583.0     0
# 995               0      1   8391224.0     0
# 996               0      1   7843973.0     0
# 997               0      1    677692.0     0
# 998               1      1    990342.0     0

# %%
dataset.shape
# Out:
# (998, 12)

# %%
srn.distplot(dataset['SALARIO']).set_title('SALARIO')
# Out:
# <ipython-input-80-3d7ea5283766>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   srn.distplot(dataset['SALARIO']).set_title('SALARIO')
# Text(0.5, 1.0, 'SALARIO')
